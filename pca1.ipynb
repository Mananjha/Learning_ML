MB 1.7 MB/s eta 0:00:01
#      ---------------------------------        6.9/8.1 MB 1.7 MB/s eta 0:00:01
#      ----------------------------------       7.0/8.1 MB 1.7 MB/s eta 0:00:01
#      -----------------------------------      7.1/8.1 MB 1.7 MB/s eta 0:00:01
#      -----------------------------------      7.2/8.1 MB 1.7 MB/s eta 0:00:01
#      ------------------------------------     7.4/8.1 MB 1.8 MB/s eta 0:00:01
#      -------------------------------------    7.5/8.1 MB 1.8 MB/s eta 0:00:01
#      -------------------------------------    7.6/8.1 MB 1.8 MB/s eta 0:00:01
#      --------------------------------------   7.7/8.1 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------  7.9/8.1 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------  7.9/8.1 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------  7.9/8.1 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------  7.9/8.1 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------  7.9/8.1 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------  7.9/8.1 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------  7.9/8.1 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------  7.9/8.1 MB 1.8 MB/s eta 0:00:01
#      ---------------------------------------  7.9/8.1 MB 1.7 MB/s eta 0:00:01
#      ---------------------------------------  8.0/8.1 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------  8.1/8.1 MB 1.7 MB/s eta 0:00:01
#      ---------------------------------------  8.1/8.1 MB 1.7 MB/s eta 0:00:01
#      ---------------------------------------- 8.1/8.1 MB 1.6 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp311-cp311-win_amd64.whl (222 kB)
#                                               0.0/222.0 kB ? eta -:--:--
#      ------------                            71.7/222.0 kB 1.9 MB/s eta 0:00:01
#      -------------------------------        184.3/222.0 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 222.0/222.0 kB 1.5 MB/s eta 0:00:00
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.58.2-cp311-cp311-win_amd64.whl (2.2 MB)
#                                               0.0/2.2 MB ? eta -:--:--
#      --                                       0.2/2.2 MB 3.1 MB/s eta 0:00:01
#      -----                                    0.3/2.2 MB 3.1 MB/s eta 0:00:01
#      ---------                                0.5/2.2 MB 3.1 MB/s eta 0:00:01
#      -----------                              0.7/2.2 MB 2.9 MB/s eta 0:00:01
#      --------------                           0.8/2.2 MB 2.8 MB/s eta 0:00:01
#      ---------------------                    1.2/2.2 MB 3.4 MB/s eta 0:00:01
#      -------------------------                1.4/2.2 MB 3.6 MB/s eta 0:00:01
#      -----------------------------            1.7/2.2 MB 3.7 MB/s eta 0:00:01
#      ------------------------------------     2.0/2.2 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------  2.2/2.2 MB 3.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.2/2.2 MB 3.6 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp311-cp311-win_amd64.whl (71 kB)
#                                               0.0/72.0 kB ? eta -:--:--
#      ---------------------------------------- 72.0/72.0 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp311-cp311-win_amd64.whl (2.7 MB)
#                                               0.0/2.7 MB ? eta -:--:--
#      ---                                      0.2/2.7 MB 4.6 MB/s eta 0:00:01
#      ------                                   0.5/2.7 MB 4.7 MB/s eta 0:00:01
#      ---------                                0.7/2.7 MB 4.6 MB/s eta 0:00:01
#      --------------                           1.0/2.7 MB 5.1 MB/s eta 0:00:01
#      -----------------                        1.2/2.7 MB 5.0 MB/s eta 0:00:01
#      --------------------                     1.4/2.7 MB 4.9 MB/s eta 0:00:01
#      ------------------------                 1.7/2.7 MB 5.0 MB/s eta 0:00:01
#      ----------------------------             1.9/2.7 MB 5.2 MB/s eta 0:00:01
#      ------------------------------           2.0/2.7 MB 4.9 MB/s eta 0:00:01
#      --------------------------------         2.2/2.7 MB 4.7 MB/s eta 0:00:01
#      ------------------------------------     2.5/2.7 MB 4.9 MB/s eta 0:00:01
#      ---------------------------------------  2.7/2.7 MB 4.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.7/2.7 MB 4.5 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#                                               0.0/111.1 kB ? eta -:--:--
#      -------------------------------------- 111.1/111.1 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.58.2 kiwisolver-1.4.8 matplotlib-3.10.3 pillow-11.2.1 pyparsing-3.2.3
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: C:\Users\DELL\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/DELL/Desktop/workshit/placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('cgpa')
plt.ylabel('package(in LPA)')
# Out:
# Text(0, 0.5, 'package(in LPA)')

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
pip install sklearn
# Out:
# Collecting sklearnNote: you may need to restart the kernel to use updated packages.
#
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: C:\Users\DELL\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.0-cp311-cp311-win_amd64.whl (10.7 MB)
#                                               0.0/10.7 MB ? eta -:--:--
#                                               0.0/10.7 MB ? eta -:--:--
#                                               0.1/10.7 MB 1.3 MB/s eta 0:00:09
#                                               0.1/10.7 MB 1.1 MB/s eta 0:00:10
#                                              0.2/10.7 MB 984.6 kB/s eta 0:00:11
#                                               0.3/10.7 MB 1.2 MB/s eta 0:00:09
#      -                                        0.3/10.7 MB 1.4 MB/s eta 0:00:08
#      -                                        0.5/10.7 MB 1.6 MB/s eta 0:00:07
#      --                                       0.6/10.7 MB 1.8 MB/s eta 0:00:06
#      --                                       0.7/10.7 MB 1.7 MB/s eta 0:00:07
#      --                                       0.7/10.7 MB 1.6 MB/s eta 0:00:07
#      ---                                      0.8/10.7 MB 1.6 MB/s eta 0:00:07
#      ---                                      0.9/10.7 MB 1.6 MB/s eta 0:00:07
#      ---                                      0.9/10.7 MB 1.6 MB/s eta 0:00:07
#      ---                                      1.1/10.7 MB 1.6 MB/s eta 0:00:06
#      ----                                     1.2/10.7 MB 1.8 MB/s eta 0:00:06
#      -----                                    1.4/10.7 MB 1.8 MB/s eta 0:00:06
#      -----                                    1.5/10.7 MB 1.9 MB/s eta 0:00:05
#      ------                                   1.6/10.7 MB 1.9 MB/s eta 0:00:05
#      ------                                   1.8/10.7 MB 2.0 MB/s eta 0:00:05
#      -------                                  2.0/10.7 MB 2.1 MB/s eta 0:00:05
#      -------                                  2.1/10.7 MB 2.1 MB/s eta 0:00:05
#      --------                                 2.3/10.7 MB 2.2 MB/s eta 0:00:04
#      --------                                 2.4/10.7 MB 2.2 MB/s eta 0:00:04
#      ---------                                2.6/10.7 MB 2.3 MB/s eta 0:00:04
#      ----------                               2.7/10.7 MB 2.3 MB/s eta 0:00:04
#      ----------                               2.9/10.7 MB 2.3 MB/s eta 0:00:04
#      -----------                              3.0/10.7 MB 2.4 MB/s eta 0:00:04
#      -----------                              3.2/10.7 MB 2.4 MB/s eta 0:00:04
#      ------------                             3.4/10.7 MB 2.5 MB/s eta 0:00:03
#      -------------                            3.6/10.7 MB 2.5 MB/s eta 0:00:03
#      -------------                            3.7/10.7 MB 2.5 MB/s eta 0:00:03
#      --------------                           3.8/10.7 MB 2.6 MB/s eta 0:00:03
#      --------------                           4.0/10.7 MB 2.6 MB/s eta 0:00:03
#      ---------------                          4.1/10.7 MB 2.6 MB/s eta 0:00:03
#      ----------------                         4.3/10.7 MB 2.6 MB/s eta 0:00:03
#      ----------------                         4.4/10.7 MB 2.6 MB/s eta 0:00:03
#      -----------------                        4.6/10.7 MB 2.6 MB/s eta 0:00:03
#      -----------------                        4.7/10.7 MB 2.7 MB/s eta 0:00:03
#      ------------------                       4.9/10.7 MB 2.7 MB/s eta 0:00:03
#      -------------------                      5.1/10.7 MB 2.7 MB/s eta 0:00:03
#      -------------------                      5.3/10.7 MB 2.8 MB/s eta 0:00:02
#      --------------------                     5.5/10.7 MB 2.8 MB/s eta 0:00:02
#      ---------------------                    5.7/10.7 MB 2.9 MB/s eta 0:00:02
#      ----------------------                   5.9/10.7 MB 2.9 MB/s eta 0:00:02
#      ----------------------                   6.1/10.7 MB 2.9 MB/s eta 0:00:02
#      -----------------------                  6.2/10.7 MB 2.9 MB/s eta 0:00:02
#      -----------------------                  6.4/10.7 MB 2.9 MB/s eta 0:00:02
#      ------------------------                 6.6/10.7 MB 2.9 MB/s eta 0:00:02
#      -------------------------                6.7/10.7 MB 2.9 MB/s eta 0:00:02
#      -------------------------                6.9/10.7 MB 3.0 MB/s eta 0:00:02
#      --------------------------               7.1/10.7 MB 3.0 MB/s eta 0:00:02
#      ---------------------------              7.2/10.7 MB 3.0 MB/s eta 0:00:02
#      ---------------------------              7.4/10.7 MB 3.0 MB/s eta 0:00:02
#      ----------------------------             7.6/10.7 MB 3.0 MB/s eta 0:00:02
#      -----------------------------            7.8/10.7 MB 3.0 MB/s eta 0:00:01
#      -----------------------------            7.9/10.7 MB 3.0 MB/s eta 0:00:01
#      ------------------------------           8.1/10.7 MB 3.0 MB/s eta 0:00:01
#      -------------------------------          8.3/10.7 MB 3.0 MB/s eta 0:00:01
#      -------------------------------          8.5/10.7 MB 3.0 MB/s eta 0:00:01
#      --------------------------------         8.6/10.7 MB 3.1 MB/s eta 0:00:01
#      --------------------------------         8.8/10.7 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------        8.9/10.7 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------        8.9/10.7 MB 3.1 MB/s eta 0:00:01
#      ----------------------------------       9.2/10.7 MB 3.0 MB/s eta 0:00:01
#      -----------------------------------      9.4/10.7 MB 3.1 MB/s eta 0:00:01
#      -----------------------------------      9.6/10.7 MB 3.1 MB/s eta 0:00:01
#      ------------------------------------     9.8/10.7 MB 3.1 MB/s eta 0:00:01
#      -------------------------------------    10.0/10.7 MB 3.1 MB/s eta 0:00:01
#      --------------------------------------   10.2/10.7 MB 3.1 MB/s eta 0:00:01
#      --------------------------------------   10.4/10.7 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  10.5/10.7 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  10.7/10.7 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  10.7/10.7 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------- 10.7/10.7 MB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\dell\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.15.2)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#                                               0.0/307.7 kB ? eta -:--:--
#      --------------------                   163.8/307.7 kB 5.0 MB/s eta 0:00:01
#      -------------------------------------  307.2/307.7 kB 3.8 MB/s eta 0:00:01
#      -------------------------------------- 307.7/307.7 kB 3.2 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.1 scikit-learn-1.7.0 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 25.1.1
# [notice] To update, run: C:\Users\DELL\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
python -m pip install --upgrade pip
# Out:
#   Cell In[19], line 1
#     python -m pip install --upgrade pip
#               ^
# SyntaxError: invalid syntax

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.ilnear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from sklearn.ilnear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn.ilnear_model'

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
Y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m = lr.coef_

# %%
b = lr.intercept_

# %%
# y = mx + b

m * 8.58 + b
# Out:
# array([3.89111601])

# %%
m * 9.5 + b
# Out:
# array([4.40443183])

# %% [raw]
# Regression Matrics

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
Y_pred=lr.predict(X_test)

# %%
Y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print("MAE",mean_absolute_error(Y_test,Y_pred))
# Out:
# MAE 0.2884710931878175

# %%
print("MSE",mean_squared_error(Y_test,Y_pred))
# Out:
# MSE 0.12129235313495527

# %%
print("RMSE",np.sqrt(mean_squared_error(Y_test,Y_pred)))
# Out:
# RMSE 0.34827051717731616

# %%
print("R2",r2_score(Y_test,Y_pred))
r2=r2_score(Y_test,Y_pred)
# Out:
# R2 0.780730147510384

# %%
# Adjust R2 Score
X_test.shape
# Out:
# (40, 1)

# %%
1-  ((1-r2)*(40-1))/(40-1-1)
# Out:
# 0.7749598882343415
